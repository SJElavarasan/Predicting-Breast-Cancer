# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
df=pd.read_csv("C:\\Users\\elava\\Downloads\\cancer (1).csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.drop(['Unnamed: 32'],axis=1,inplace=True)

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
model =LabelEncoder()
df['diagnosis_Numeric']=model.fit_transform(df.diagnosis)

# %%
df.drop(['diagnosis'], axis=1,inplace=True)

# %%
df
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
X=df.drop(['diagnosis_Numeric'],axis=1)
y=df.diagnosis_Numeric

# %%
X
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_1=RandomForestClassifier(n_estimators=10)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

# %%
model_1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred=model_1.predict(X_test)

# %%
y_pred_train = model_1.predict(X_train)
accuracy_train = accuracy_score(y_test, y_pred)
print("Accuracy on training data:", accuracy_train)
# Out:
# Accuracy on training data: 0.9415204678362573

# %%
precision_score = roc_auc_score(y_test, y_pred)
print("precision_score on training data:", precision_score)
# Out:
# precision_score on training data: 0.931293808411215

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_pred)

# %%
plt.figure(figsize=(17,7))
sns.heatmap(cm,annot=True)
plt.xlabel('Truth')
plt.ylabel('Prediction')
plt.show()

# %%
y_pred_test = model_1.predict(X_test)
print("Accuracy on training data:", accuracy_train)
# Out:
# Accuracy on training data: 1.0

# %%
y_pred_train = model_1.predict(X_train)
print("Accuracy on training data:", accuracy_train)
# Out:
# Accuracy on training data: 1.0

# %%
y_pred_train = model_1.predict(X_train)
recall_score = recall_score(y_true=y_train, y_pred=y_pred_train)
print("Accuracy on training data:", recall_scor)
# Out:
# Accuracy on training data: 1.0

# %%
# Histograms for Feature Distributions
plt.figure(figsize=(15, 6))
for i, feature in enumerate(data.feature_names[:10]):
    plt.subplot(2, 5, i + 1)
    sns.histplot(data=df, x=feature, bins=20, kde=True)
    plt.title(f'{feature} Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='target')
plt.title('Class Distribution')
plt.xlabel('Target')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Scatter Plots and Pair Plots to Visualize Relationships Between Features
sns.pairplot(df.sample(100), vars=data.feature_names[:5], hue='target')
# Out:
# C:\Users\elava\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Box Plots and Violin Plots to Compare Feature Distributions Across Different Classes or Groups
plt.figure(figsize=(12, 6))
for i, feature in enumerate(data.feature_names[:5]):
    plt.subplot(2, 5, i + 1)
    sns.boxplot(data=df, x='target', y=feature)
    plt.title(f'{feature} Distribution by Class')

# %%
plt.figure(figsize=(12, 6))
for i, feature in enumerate(data.feature_names[:5]):
    plt.subplot(2, 5, i + 1)
    sns.violinplot(data=df, x='target', y=feature)
    plt.title(f'{feature} Distribution by Class')

# %%
# Heatmap to Visualize Correlations Between Features
plt.figure(figsize=(25, 18))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Assuming 'mean radius' for survival analysis
durations = df['mean radius']
event_observed = df['target']  # Assuming target represents event (1) or censored (0)

# Fit the Kaplan-Meier estimator
kmf.fit(durations, event_observed=event_observed)

# Plot the survival curve
plt.figure(figsize=(8, 6))
kmf.plot()
plt.title('Survival Curve for Mean Radius')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model = AdaBoostClassifier(n_estimators=50)

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.9649122807017544
